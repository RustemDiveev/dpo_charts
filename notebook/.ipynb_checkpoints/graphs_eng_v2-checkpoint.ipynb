# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

import numpy as np

# %%
LEGEND_FONTSIZE = 9

# %%
def create_plot_1(ax):
    # Данные
    years = [2020, 2021, 2022, 2023, 2024]
    total_programs = [211523, 217917, 261058, 272568, 309398]
    network_programs = [4885, 6083, 4704, 5212, 5760]
    
    # Рассчет процента сетевых программ
    percent_network = [n/t*100 for n, t in zip(network_programs, total_programs)]

    # Настройка позиций для столбцов
    x = np.arange(len(years))
    width = 0.35
    
    # Столбцы для абсолютных значений
    bars1 = ax.bar(x - width/2, total_programs, width, label='Все программы (шт)', color='lightblue')
    bars2 = ax.bar(x + width/2, network_programs, width, label='Сетевая форма (шт)', color='steelblue')
    
    # Настройка основной оси Y
    ax.set_xlabel('Годы')
    ax.set_ylabel('Количество программ (шт)')
    ax.set_xticks(x)
    ax.set_xticklabels(years)
    ax.legend(loc='upper left', fontsize=LEGEND_FONTSIZE)
    ax.set_ylim(0, max(total_programs) * 1.15)
    
    # Создание второй оси Y для процентов
    ax2 = ax.twinx()
    ax2.plot(x, percent_network, color='crimson', marker='o', linewidth=2, label='Доля сетевых программ (%)')
    ax2.set_ylabel('Процент сетевых программ (%)')
    ax2.set_ylim(0, 15)
    ax2.legend(loc='upper right', fontsize=LEGEND_FONTSIZE)
    
    # Добавление подписей значений
    for i, (tot, net, perc) in enumerate(zip(total_programs, network_programs, percent_network)):
        ax.text(i - width/2, tot + 10, str(tot), ha='center')
        ax.text(i + width/2, net + 10, str(net), ha='center')
        ax2.text(i, perc + 0.5, f'{perc:.1f}%', ha='center', color='crimson')

    # Дополнительные настройки
    ax.set_title('Программы повышения квалификации')
    ax.grid(axis='y', alpha=0.3)

# %%
def create_plot_2(ax):
    # Данные
    years = [2020, 2021, 2022, 2023, 2024]
    total_programs = [55211, 52300, 60635, 65184, 67032]
    network_programs = [1874, 1738, 1516, 1613, 1697]

    # Рассчет процента сетевых программ
    percent_network = [n/t*100 for n, t in zip(network_programs, total_programs)]
    
    # Настройка позиций для столбцов
    x = np.arange(len(years))
    width = 0.35
    
    # Столбцы для абсолютных значений
    bars1 = ax.bar(x - width/2, total_programs, width, label='Все программы (шт)', color='lightblue')
    bars2 = ax.bar(x + width/2, network_programs, width, label='Сетевая форма (шт)', color='steelblue')
    
    # Настройка основной оси Y
    ax.set_xlabel('Годы')
    ax.set_ylabel('Количество программ (шт)')
    ax.set_xticks(x)
    ax.set_xticklabels(years)
    ax.legend(loc='upper left', fontsize=LEGEND_FONTSIZE)
    ax.set_ylim(0, max(total_programs) * 1.15)
    
    # Создание второй оси Y для процентов
    ax2 = ax.twinx()
    ax2.plot(x, percent_network, color='crimson', marker='o', linewidth=2, label='Доля сетевых программ (%)')
    ax2.set_ylabel('Процент сетевых программ (%)')
    ax2.set_ylim(0, 15)
    ax2.legend(loc='upper right', fontsize=LEGEND_FONTSIZE)
    
    # Добавление подписей значений
    for i, (tot, net, perc) in enumerate(zip(total_programs, network_programs, percent_network)):
        ax.text(i - width/2, tot + 10, str(tot), ha='center')
        ax.text(i + width/2, net + 10, str(net), ha='center')
        ax2.text(i, perc + 0.5, f'{perc:.1f}%', ha='center', color='crimson')

    ax.set_title('Программы профессиональной переподготовки')
    ax.grid(axis='y', alpha=0.3)

# %%
def create_plot_3(ax):
    # Данные
    years = [2020, 2021, 2022, 2023, 2024]
    total_learners = [6014631, 6292306, 7414006, 7510345, 7459425]
    network_form_learners = [143831, 245708, 198874, 239046, 225097]
    
    # Рассчет процента слушателей сетевых программ от общего количества слушателей
    percent_network = [n/t*100 for n, t in zip(network_form_learners, total_learners)]
    
    # Настройка позиций для столбцов
    x = np.arange(len(years))
    width = 0.35
    
    # Столбцы для абсолютных значений
    # bars1 = ax.bar(x - width/2, total_learners, width, label='Total number of listeners (people)', color='lightblue')
    bars1 = ax.bar(x - width/2, total_learners, width, label='Количество слушателей (чел)', color='lightblue')
    # bars2 = ax.bar(x + width/2, network_form_learners, width, label='Total number of listeners - network form (people)', color='steelblue')
    bars2 = ax.bar(x + width/2, network_form_learners, width, label='Количество слушателей - сетевая форма (чел)', color='steelblue')
    
    # Настройка основной оси Y
    # ax.set_xlabel('Years')
    ax.set_xlabel('Годы')
    # ax.set_ylabel('Number of listeners (people)')
    ax.set_ylabel('Количество слушателей (чел)')
    ax.set_xticks(x)
    ax.set_xticklabels(years)
    ax.legend(loc='upper left', fontsize=LEGEND_FONTSIZE)
    ax.set_ylim(0, max(total_learners) * 1.15)

    # Функция для форматирования чисел с разделителями тысяч
    def format_thousands(x, pos):
        return f'{int(x):,}'.replace(',', ' ')
    
    # Применяем форматирование к левой оси
    ax.yaxis.set_major_formatter(FuncFormatter(format_thousands))
    
    # Создание второй оси Y для процентов
    ax2 = ax.twinx()
    # ax2.plot(x, percent_network, color='crimson', marker='o', linewidth=2, label='Part of listeners of network programs (%)')
    ax2.plot(x, percent_network, color='crimson', marker='o', linewidth=2, label='Доля слушателей сетевых программ (%)')
    # ax2.set_ylabel('Percentage of network program listeners (%)')
    ax2.set_ylabel('Процент слушателей сетевых программ (%)')
    ax2.set_ylim(0, 15)
    ax2.legend(loc='upper right', fontsize=LEGEND_FONTSIZE)
    
    # Добавление подписей значений
    for i, (tot, net, perc) in enumerate(zip(total_learners, network_form_learners, percent_network)):
        ax.text(i - width/2, tot + 10, str(tot), ha='center')
        ax.text(i + width/2, net + 10, str(net), ha='center')
        ax2.text(i, perc + 0.5, f'{perc:.1f}%', ha='center', color='crimson')
    
    # Дополнительные настройки
    # ax.set_title('Advanced training programs - listeners')
    ax.set_title('Программы повышения квалификации - слушатели')
    ax.grid(axis='y', alpha=0.3)

# %%
def create_plot_4(ax):
    # Данные
    years = [2020, 2021, 2022, 2023, 2024]
    total_learners = [649202, 669026, 772577, 869097, 981248]
    network_form_learners = [23333, 26361, 39230, 43159, 47180]
    
    # Рассчет процента слушателей сетевых программ от общего количества слушателей
    percent_network = [n/t*100 for n, t in zip(network_form_learners, total_learners)]
    
    # Настройка позиций для столбцов
    x = np.arange(len(years))
    width = 0.35
    
    # Столбцы для абсолютных значений
    # bars1 = ax.bar(x - width/2, total_learners, width, label='Total number of listeners (people)', color='lightblue')
    bars1 = ax.bar(x - width/2, total_learners, width, label='Количество слушателей (чел)', color='lightblue')
    # bars2 = ax.bar(x + width/2, network_form_learners, width, label='Total number of listeners - network form (people)', color='steelblue')
    bars2 = ax.bar(x + width/2, network_form_learners, width, label='Количество слушателей - сетевая форма (чел)', color='steelblue')
    
    # Настройка основной оси Y
    # ax.set_xlabel('Years')
    ax.set_xlabel('Годы')
    # ax.set_ylabel('Number of listeners (people)')
    ax.set_ylabel('Количество слушателей (чел)')
    ax.set_xticks(x)
    ax.set_xticklabels(years)
    ax.legend(loc='upper left', fontsize=LEGEND_FONTSIZE)
    ax.set_ylim(0, max(total_learners) * 1.15)

    # Функция для форматирования чисел с разделителями тысяч
    def format_thousands(x, pos):
        return f'{int(x):,}'.replace(',', ' ')
    
    # Применяем форматирование к левой оси
    ax.yaxis.set_major_formatter(FuncFormatter(format_thousands))
    
    # Создание второй оси Y для процентов
    ax2 = ax.twinx()
    # ax2.plot(x, percent_network, color='crimson', marker='o', linewidth=2, label='Part of listeners of network programs (%)')
    ax2.plot(x, percent_network, color='crimson', marker='o', linewidth=2, label='Доля слушателей сетевых программ (%)')
    # ax2.set_ylabel('Percentage of network program listeners (%)')
    ax2.set_ylabel('Процент слушателей сетевых программ (%)')
    ax2.set_ylim(0, 15)
    ax2.legend(loc='upper right', fontsize=LEGEND_FONTSIZE)
    
    # Добавление подписей значений
    for i, (tot, net, perc) in enumerate(zip(total_learners, network_form_learners, percent_network)):
        ax.text(i - width/2, tot + 10, str(tot), ha='center')
        ax.text(i + width/2, net + 10, str(net), ha='center')
        ax2.text(i, perc + 0.5, f'{perc:.1f}%', ha='center', color='crimson')
    
    # Дополнительные настройки
    # ax.set_title('Professional retraining programs - listeners')
    ax.set_title('Программы профессиональной переподготовки - слушатели')
    ax.grid(axis='y', alpha=0.3)

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

create_plot_1(ax=axes[0,0])
create_plot_2(ax=axes[0,1])
create_plot_3(ax=axes[1,0])
create_plot_4(ax=axes[1,1])

# Настраиваем расстояние между подграфиками
plt.tight_layout()
# Показываем график
plt.show()
